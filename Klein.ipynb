# %% [markdown]
# # Introductions

# %%
import os
os.environ["BLAS_NUM_THREADS"] = "1" 
os.environ["OPENBLAS_NUM_THREADS"] = "1" # 

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scanpy as sc
import scvelo as scv
from tqdm import tqdm

import statsmodels.formula.api as sm
import pandas as pd
from scipy.stats import poisson, gamma, norm

# %%
from multiprocessing import Pool

def get_s(data):
    gene_mask = (np.mean(data,axis=0)>0) & (np.var(data,axis=0)>0) 
    X = data[:,gene_mask]
    n,p = X.shape
    X_cov = np.cov(X,rowvar=False)
    X_mean = np.mean(X,axis=0)
    X_rho = X_cov/X_mean[:,None]/X_mean[None,:]
    s = (np.sum(X_rho)-np.sum(np.diag(X_rho)))/((p-1)*p)
    return s

def bootstrap_s(X,B=10,cores=10):
    n,p = X.shape
    Input_args = []
    for b in range(B):
        sample_idx = np.random.choice(n,n,replace=True)
        sample = X[sample_idx]
        Input_args.append(sample)
            
    with Pool(cores) as pool:      
        s = pool.map(get_s, Input_args, chunksize=1)

    return s

# %%
def CCC(y_pred, y_true):
    # Pearson product-moment correlation coefficients
    cor = np.corrcoef(y_true, y_pred)[0][1]
    
    # Mean
    mean_true = np.mean(y_true)
    mean_pred = np.mean(y_pred)
    
    # Variance
    var_true = np.var(y_true)
    var_pred = np.var(y_pred)
    
    # Standard deviation
    sd_true = np.std(y_true)
    sd_pred = np.std(y_pred)
    
    # Calculate CCC
    numerator = 2 * cor * sd_true * sd_pred
    denominator = var_true + var_pred + (mean_true - mean_pred)**2
    
    return numerator / denominator

# %%
def select_genes(U,S,gene_names,mean_min=0.1,var_min=1):
    gene_mask = (np.mean(S,axis=0)>0) & (np.mean(U,axis=0)>0) & (np.var(S,axis=0)>0) & (np.var(U,axis=0)>0)
    s = S[:,gene_mask]
    u = U[:,gene_mask]
    gene_names = gene_names[gene_mask]
    cov = np.cov(u,s,rowvar=False)
    s_mean = np.mean(s,axis=0)
    u_mean = np.mean(u,axis=0)
    X_mean = np.append(u_mean,s_mean)
    p = s.shape[1]
    rho = cov/X_mean[:,None]/X_mean[None,:]
    rho_s = rho[p:,p:]
    rho_u = rho[:p,:p]
    rho_us = rho[:p,p:]
    s = (np.sum(rho_us)-np.sum(np.diag(rho_us)))/(p-1)/p
    genes_mask = (s_mean>mean_min) & (u_mean>mean_min) & (np.abs(np.diag(rho_us)-s)>var_min)
    return gene_names[genes_mask]

# %% [markdown]
# # Pure RNA + ERCC

# %%
pure = pd.read_csv('data/Klein/GSM1599501_K562_pure_RNA.csv')

# %%
var_names = np.array(pure.to_numpy().T[0,],dtype=str)
data = np.array(pure.to_numpy().T[1:,],dtype=float)
data.shape
# Out:
# (953, 25435)

# %%
plt.hist(data.sum(1))
# Out:
# (array([ 30.,  97., 245., 362., 175.,  38.,   4.,   0.,   0.,   2.]),
#  array([12721. , 18829.9, 24938.8, 31047.7, 37156.6, 43265.5, 49374.4,
#         55483.3, 61592.2, 67701.1, 73810. ]),
#  <BarContainer object of 10 artists>)

# %%
gene_mask = (np.mean(data,axis=0)>0.1) & (np.var(data,axis=0)>0) 
X = data[:,gene_mask]
cov = np.cov(X,rowvar=False)
X_bar = np.mean(X,axis=0)
X_var = np.diag(cov)

rho = cov/X_bar[:,None]/X_bar[None,:]
s = (np.sum(rho)-np.sum(np.diag(rho)))/(len(rho)-1)/len(rho)
print('s =',s)
# Out:
# s = 0.046995770118103714

# %%
matplotlib.rc('font', size=20)
eta_0 = -1
Ec = 0.071
a = 1 + Ec * (s + 1) * (1 + eta_0)
plt.axhline(y=s, c='b',label='s='+str(np.around(s,3)))
plt.scatter(X_bar, a/X_bar + s,c='r',alpha=1, s=10,label=r'$\frac{1}{\mu}$ + s')
plt.scatter(X_bar, X_var/X_bar**2,c='k',alpha=1, s=0.1)
plt.xlabel(r'$\mu$',fontsize=24)
plt.ylabel(r'$CV^2$',fontsize=24)
plt.title("Pure RNA",fontsize=28)
plt.xscale('log')
plt.yscale('log')
plt.legend()

# %%
matplotlib.rc('font', size=20)
eta_0 = -1
Ec = 0.071
a = 1 + Ec * (s + 1) * (1 + eta_0)
plt.axhline(y=a, c='orange',label='s='+str(np.around(s,3)))
plt.scatter(X_bar, X_var/X_bar-s*X_bar,c='k',alpha=1, s=0.1)

eta_0 = 0
Ec = 0.071
a = 1 + Ec * (s + 1) * (1 + eta_0)
plt.axhline(y=a, c='r',label='s='+str(np.around(s,3)))


plt.xlabel(r'$\mu$',fontsize=24)
plt.ylabel(r'$CV^2$',fontsize=24)
plt.title("Pure RNA",fontsize=28)
plt.xscale('log')
plt.yscale('log')
#plt.legend();

# %%
a = 1 
plt.axhline(y=s, c='r')
plt.scatter(X_bar, a/X_bar + s,c='b',alpha=1, s=1)
plt.scatter(X_bar, X_var/X_bar**2,c='k',alpha=1, s=1)
plt.xlabel(r'$\mu$')
plt.ylabel(r'$\sigma^2$')
plt.title("variance-mean relations of pure RNA")
plt.yscale('log')

# %%
Ec = 0.071
plt.axhline(y=(1+s)*Ec, c='r')
plt.axhline(y=0, c='y')
plt.scatter(X_bar, (X_var-X_bar)/X_bar-s*X_bar,c='k',alpha=1, s=1)
plt.xlabel(r'$\mu$')
plt.ylabel(r'$\sigma^2$')
plt.title("variance-mean relationships of PBMC dataset")
# Out:
# Text(0.5, 1.0, 'variance-mean relationships of PBMC dataset')

# %%
plt.hist((X_var-X_bar)/X_bar-s*X_bar,bins=1000);
plt.axvline(x=0,c='r')
plt.axvline(x=Ec*(1+s),c='orange')

# %% [markdown]
# ## Read depth distribution

# %%
x = np.arange(0,80000,100)
x_ = np.random.poisson(data.sum(1).mean(),size=len(data))
plt.hist(x_,bins=x,density=True);

# %%
plt.hist(data.sum(1),density=True);
plt.title('total counts distribution')
# Out:
# Text(0.5, 1.0, 'total counts distribution')

# %%
x = data.sum(1)
x.max()
# Out:
# 73810.0

# %%
import matplotlib.pyplot as plt
from math import factorial, exp, log
from scipy import integrate, special
from tqdm import tqdm

def f_func(x,z):
    I=len(z)
    J=len(x)
    z=np.reshape(z,(I,1))
    x=np.reshape(x,(1,J))
    Z=np.repeat(z,J,axis=1)
    X=np.repeat(x,I,axis=0)    
    return np.exp(np.log(Z+10**(-10))*X-z-special.gammaln(x+1))

# parameters
ite_num=10
z_range=80000  

# initialization
n=len(x)
dz=1
z=np.arange(0,z_range+dz,dz) # here use z to denote the discretized t
pi=np.ones_like(z)/z_range
z=np.reshape(z,(len(z),1))


unique, counts = np.unique(x, return_counts=True)
f=f_func(unique,z)
L=np.zeros([ite_num,len(unique)])

# iteration
for i in tqdm(range(ite_num)):  
    f_int=integrate.trapz(f*pi[:,None],z,axis=0) 
    pi=pi*np.sum(counts[None,:]*f/f_int,axis=1)/n
    L[i,:]=f_int
# Out:
# 100%|██████████| 10/10 [00:10<00:00,  1.08s/it]

# %%
plt.scatter(z,pi,s=0.1);

# %%
plt.scatter(z/x.mean(),pi*x.mean(),s=0.01);
plt.title('read depth distribution')
# Out:
# Text(0.5, 1.0, 'read depth distribution')

# %% [markdown]
# ### Suppose read depth follows Gamma distribution

# %%
m1 = (z[:,0]*pi).sum()
m2 = ((z[:,0]-m1)**2*pi).sum()
m3 = ((z[:,0]-m1)**3*pi).sum()
m4 = ((z[:,0]-m1)**4*pi).sum()
m5 = ((z[:,0]-m1)**5*pi).sum()
m6 = ((z[:,0]-m1)**6*pi).sum()

# %%
alpha = m1**2/m2
beta = alpha
alpha
# Out:
# 22.212180247161008

# %%
plt.scatter(z/m1,pi*m1,s=0.01);
plt.plot(np.linspace(0,3,301),gamma.pdf(np.linspace(0,3,301),a=alpha,scale=1/beta),'r.')
plt.title('read depth distribution')
# Out:
# Text(0.5, 1.0, 'read depth distribution')

# %%
skewness = m3/(m2**1.5)
skewness
# Out:
# 0.10815374796191585

# %%
2/np.sqrt(alpha)
# Out:
# 0.4243599613196957

# %% [markdown]
# ### Gaussian

# %%
mu = 1
sigma = np.sqrt(m2/m1**2)

# %%
m4/(3*m2**2)
# Out:
# 1.679080296498339

# %%
m6/(15*m2**3)
# Out:
# 5.700083262540179

# %%
plt.scatter(z/m1,pi*m1,s=0.01,color='gray');
plt.plot(np.linspace(0,3,301),norm.pdf(np.linspace(0,3,301),loc=1,scale=sigma),'.',c='b',label='Gaussian')
plt.plot(np.linspace(0,3,301),gamma.pdf(np.linspace(0,3,301),a=alpha,scale=1/beta),'r.',label='Gamma')
plt.title('read depth distribution')
plt.legend()

# %% [markdown]
# ### lognormal

# %%
from scipy.stats import lognorm

# %%
expsigma2 = m2/m1**2 + 1
sigma = np.sqrt(np.log(expsigma2))
mu = -sigma**2/2
scale = np.exp(mu)

# %%
(expsigma2 + 2)  * np.sqrt(expsigma2-1)
# Out:
# 0.6460923577396745

# %%
(z[:,0]**2*pi).sum()/((z[:,0]*pi).sum())**2 - 1
# Out:
# 0.04502034419281209

# %%
plt.scatter(z/m1,pi*m1,s=0.01,color='gray');
plt.scatter(np.linspace(0,3,3001),norm.pdf(np.linspace(0,3,3001),loc=1,scale=sigma),s=1,c='b',label='Gaussian')
plt.scatter(np.linspace(0,3,3001),gamma.pdf(np.linspace(0,3,3001),a=alpha,scale=1/beta),s=1,c='r',label='Gamma')
plt.scatter(np.linspace(0,3,3001),lognorm.pdf(np.linspace(0,3,3001),s=sigma,scale=scale),s=1,c='g',label='lognorm')
plt.title('Normalized read depth distribution')
plt.legend()

# %% [markdown]
# ## Pgenes

# %%
Pgene_mask = (X_bar > 0) & (np.abs(X_var/(a*X_bar + s*X_bar**2)-1) < 0.1)
Pgenes = var_names[gene_mask][Pgene_mask]
print(np.sum(Pgene_mask))

plt.scatter(X_bar[Pgene_mask], a/X_bar[Pgene_mask] + s, c='r', s=20)
plt.scatter(X_bar, X_var/X_bar**2,c='lightgray',alpha=1, s=0.1)
plt.scatter(X_bar[Pgene_mask], X_var[Pgene_mask]/X_bar[Pgene_mask]**2,c='k', s=1, label=str(np.around(100*np.mean(Pgene_mask)),1))+"%")
plt.xlabel(r'$\mu$')
plt.ylabel(r'CV')
plt.xscale('log')
plt.yscale('log')
plt.legend(loc="upper right")
# Out:
# 23898

# %%
old_Pgenes_s = s
print('old Pgenes_s =', old_Pgenes_s)
Pgene_mask = (X_bar > 0) & (np.abs(X_var/(a*X_bar + old_Pgenes_s*X_bar**2)-1)<0.1)
Pgenes = var_names[gene_mask][Pgene_mask]
print(np.sum(Pgene_mask))

x=X[:,Pgene_mask]
x_cov = np.cov(x,rowvar=False)
x_bar = np.mean(x,axis=0)
x_var = np.diag(x_cov)
x_rho = x_cov/x_bar[:,None]/x_bar[None,:]
new_Pgenes_s = (np.sum(x_rho)-np.sum(np.diag(x_rho)))/(len(x_rho)-1)/len(x_rho)
print('new Pgenes_s =',new_Pgenes_s)
# Out:
# old Pgenes_s = 0.048379452311131985
# 23898
# new Pgenes_s = 0.048044352846043685

# %%
x=X[:,Pgene_mask]
fig,ax = plt.subplots(1,1,figsize=(6,4))
ax.scatter(data.sum(axis=1)/data.sum(axis=1).mean(),x.sum(axis=1)/x.sum(axis=1).mean(),s=1);
ax.plot(x.sum(axis=1)/x.sum(axis=1).mean(),x.sum(axis=1)/x.sum(axis=1).mean(),c='grey');

# %% [markdown]
# ## Bootstrap

# %%
s_bootstrap = bootstrap_s(X,B=100,cores=10)

# %%
plt.hist(s_bootstrap,color='lightgray',bins=10,density=True)
plt.axvline(x=s,color='lightsteelblue',linewidth=5)

# %% [markdown]
# # ES d0

# %%
d0 = pd.read_csv('data/Klein/GSM1599494_ES_d0_main.csv',)

# %%
data = np.array(d0.to_numpy().T[1:,],dtype=float)
var_names = np.array(d0.to_numpy().T[0,],dtype=str)
data.shape
# Out:
# (933, 24174)

# %%
tc = data.sum(1)
plt.hist(tc);
tc.var()/tc.mean()**2
# Out:
# 0.13106269958211686

# %%
gene_mask = (np.mean(data,axis=0)>0) & (np.var(data,axis=0)>0) 
X = data[:,gene_mask]
cov = np.cov(X,rowvar=False)
X_bar = np.mean(X,axis=0)
X_var = np.diag(cov)

rho = cov/X_bar[:,None]/X_bar[None,:]
s = (np.sum(rho)-np.sum(np.diag(rho)))/(len(rho)-1)/len(rho)
print('s =',s)
# Out:
# s = 0.14059093136610995

# %%
matplotlib.rc('font', size=20)
eta_0 = -1
Ec = 0.071
a = 1 + Ec * (s + 1) * (1 + eta_0)
plt.axhline(y=s, c='b',label='s='+str(np.around(s,3)))
plt.scatter(X_bar, a/X_bar + s,c='r',alpha=1, s=10,label=r'$\frac{1}{\mu}$ + s')
plt.scatter(X_bar, X_var/X_bar**2,c='k',alpha=1, s=0.1)
plt.xlabel(r'$\mu$',fontsize=24)
plt.ylabel(r'$CV^2$',fontsize=24)
plt.title("Embryonic Stem Cells",fontsize=28)
plt.xscale('log')
plt.yscale('log')
plt.legend()

# %%
Pgene_mask = (X_bar > 0) & (np.abs(X_var/(a*X_bar + s*X_bar**2)-1) < 0.1)
Pgenes = var_names[gene_mask][Pgene_mask]
print(np.sum(Pgene_mask))

x = X[:,Pgene_mask]
x_cov = np.cov(x,rowvar=False)
x_bar = np.mean(x,axis=0)
x_var = np.diag(x_cov)

x_rho = x_cov/x_bar[:,None]/x_bar[None,:]
Pgenes_s = (np.sum(x_rho)-np.sum(np.diag(x_rho)))/(len(x_rho)-1)/len(x_rho)
print('Pgenes_s =',Pgenes_s)

matplotlib.rc('font', size=18)
a = 1 
plt.axhline(y=Pgenes_s, c='b',label='s='+str(np.around(Pgenes_s,4)))
plt.scatter(X_bar, a/X_bar + Pgenes_s ,c='r',alpha=1, s=10, label=r'$\frac{1}{\mu}$ + s')
plt.scatter(X_bar, X_var/X_bar**2,c='lightgray',alpha=1, s=0.1)
plt.scatter(X_bar[Pgene_mask], X_var[Pgene_mask]/X_bar[Pgene_mask]**2,c='k', s=1, label=str(np.around(100*np.sum(Pgene_mask)/len(X_bar),1))+"%")
plt.xlabel(r'$\mu$')
plt.ylabel(r'$CV^2$',fontsize=24)
plt.xscale('log')
plt.yscale('log')
plt.legend()
# Out:
# 14809
# Pgenes_s = 0.13973288941803463

# %%
plt.hist((x_var-x_bar)/x_bar-0.14*x_bar,bins=1000);
plt.axvline(x=0,c='r')
plt.axvline(x=Ec*(1+s),c='orange')

# %%
x=X[:,Pgene_mask]
fig,ax = plt.subplots(1,1,figsize=(6,4))
ax.scatter(x.sum(axis=1)/x.sum(axis=1).mean(),data.sum(axis=1)/data.sum(axis=1).mean(),s=10);
ax.plot(x.sum(axis=1)/x.sum(axis=1).mean(),x.sum(axis=1)/x.sum(axis=1).mean(),c='grey');
ax.text(0.9, 0.2, "CCC="+str(np.around(CCC(data.sum(axis=1)/data.sum(axis=1).mean(),x.sum(axis=1)/x.sum(axis=1).mean()))), horizontalalignment='right', 
                 verticalalignment='top', transform=ax.transAxes, color="black",fontsize=20);
ax.set_xlabel("normalized total counts \n (non variable genes)")
ax.set_ylabel("normalized total counts \n (all genes)")
ax.set_title("Embryonic Stem Cells")
# Out:
# Text(0.5, 1.0, 'Embryonic Stem Cells')

# %%
s_bootstrap = bootstrap_s(X,B=100,cores=10)

# %%
matplotlib.rc('font', size=16)
plt.hist(s_bootstrap,color='lightgray',bins=10)
plt.axvline(x=s,color='lightsteelblue',linewidth=5,label="original s")
plt.xlabel("s",fontsize=24)
plt.ylabel("frequency",fontsize=24)
plt.legend()

# %% [markdown]
# # d2

# %%
d2 = pd.read_csv('data/Klein/GSM1599497_ES_d2_LIFminus.csv')

# %%
data = np.array(d2.to_numpy().T[1:,],dtype=float)
var_names = np.array(d2.to_numpy().T[0,],dtype=str)
data.shape
# Out:
# (303, 24174)

# %%
tc = data.sum(1)
plt.hist(tc);
tc.var()/tc.mean()**2
# Out:
# 0.1302809291294804

# %%
gene_mask = (np.mean(data,axis=0)>0) & (np.var(data,axis=0)>0) 
X = data[:,gene_mask]
cov = np.cov(X,rowvar=False)
X_bar = np.mean(X,axis=0)
X_var = np.diag(cov)

rho = cov/X_bar[:,None]/X_bar[None,:]
s = (np.sum(rho)-np.sum(np.diag(rho)))/(len(rho)-1)/len(rho)
print('s =',s)
# Out:
# s = 0.13781806983204858

# %%
matplotlib.rc('font', size=18)
eta_0 = -1
Ec = 0.04
a = 1 + Ec * (s + 1) * (1 + eta_0)
plt.axhline(y=s, c='b',label='s='+str(np.around(s,3)))
plt.scatter(X_bar, a/X_bar + s,c='r',alpha=1, s=10,label=r'$\frac{1}{\mu}$ + s')
plt.scatter(X_bar, X_var/X_bar**2,c='k',alpha=1, s=0.1)
plt.xlabel(r'$\mu$',fontsize=24)
plt.ylabel(r'$CV^2$',fontsize=24)
plt.title("D2",fontsize=28)
plt.xscale('log')
plt.yscale('log')
plt.legend()

# %%
Pgene_mask = (X_bar > 0) & (np.abs(X_var/(a*X_bar + s*X_bar**2)-1) < 0.1)
Pgenes = var_names[gene_mask][Pgene_mask]
print(np.sum(Pgene_mask))

plt.scatter(X_bar[Pgene_mask], a/X_bar[Pgene_mask] + s, c='r', s=20)
plt.scatter(X_bar, X_var/X_bar**2,c='lightgray',alpha=1, s=0.1)
plt.scatter(X_bar[Pgene_mask], X_var[Pgene_mask]/X_bar[Pgene_mask]**2,c='k', s=1, label=str(np.around(100*np.sum(Pgene_mask)/len(X_bar),1))+"%")
plt.xlabel(r'$\mu$')
plt.ylabel(r'CV')
plt.xscale('log')
plt.yscale('log')
plt.legend(loc="upper right")
# Out:
# 16673

# %%
x=X[:,Pgene_mask]
fig,ax = plt.subplots(1,1,figsize=(6,4))
ax.scatter(x.sum(axis=1)/x.sum(axis=1).mean(),data.sum(axis=1)/data.sum(axis=1).mean(),s=1);
ax.plot(x.sum(axis=1)/x.sum(axis=1).mean(),x.sum(axis=1)/x.sum(axis=1).mean(),c='grey');

# %%
s_bootstrap = bootstrap_s(X,B=10,cores=10)
plt.hist(s_bootstrap,color='lightgray',bins=10,density=True)
plt.axvline(x=s,color='lightsteelblue',linewidth=5)

# %% [markdown]
# # d4

# %%
d4 = pd.read_csv('data/Klein/GSM1599498_ES_d4_LIFminus.csv',)
data = np.array(d4.to_numpy().T[1:,],dtype=float)
var_names = np.array(d4.to_numpy().T[0,],dtype=str)
data.shape
# Out:
# (683, 24174)

# %%
tc = data.sum(1)
plt.hist(tc);
tc.var()/tc.mean()**2
# Out:
# 0.12155637126507216

# %%
gene_mask = (np.mean(data,axis=0)>0) & (np.var(data,axis=0)>0) 
X = data[:,gene_mask]
cov = np.cov(X,rowvar=False)
X_bar = np.mean(X,axis=0)
X_var = np.diag(cov)

rho = cov/X_bar[:,None]/X_bar[None,:]
s = (np.sum(rho)-np.sum(np.diag(rho)))/(len(rho)-1)/len(rho)
print('s =',s)
# Out:
# s = 0.12947372620175726

# %%
matplotlib.rc('font', size=18)
eta_0 = -1
Ec = 0.04
a = 1 + Ec * (s + 1) * (1 + eta_0)
plt.axhline(y=s, c='b',label='s='+str(np.around(s,3)))
plt.scatter(X_bar, a/X_bar + s,c='r',alpha=1, s=10,label=r'$\frac{1}{\mu}$ + s')
plt.scatter(X_bar, X_var/X_bar**2,c='k',alpha=1, s=0.1)
plt.xlabel(r'$\mu$',fontsize=24)
plt.ylabel(r'$CV^2$',fontsize=24)
plt.title("D4",fontsize=28)
plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper right')

# %%
Pgene_mask = (X_bar > 0) & (np.abs(X_var/(a*X_bar + s*X_bar**2)-1) < 0.1)
Pgenes = var_names[gene_mask][Pgene_mask]
print(np.sum(Pgene_mask))

plt.scatter(X_bar[Pgene_mask], a/X_bar[Pgene_mask] + s, c='r', s=20)
plt.scatter(X_bar, X_var/X_bar**2,c='lightgray',alpha=1, s=0.1)
plt.scatter(X_bar[Pgene_mask], X_var[Pgene_mask]/X_bar[Pgene_mask]**2,c='k', s=1, label=str(np.around(100*np.sum(Pgene_mask)/len(X_bar),1))+"%")
plt.xlabel(r'$\mu$')
plt.ylabel(r'CV')
plt.xscale('log')
plt.yscale('log')
plt.legend(loc="upper right")
# Out:
# 19313

# %%
x=X[:,Pgene_mask]
fig,ax = plt.subplots(1,1,figsize=(6,4))
ax.scatter(data.sum(axis=1)/data.sum(axis=1).mean(),x.sum(axis=1)/x.sum(axis=1).mean(),s=1);
ax.plot(x.sum(axis=1)/x.sum(axis=1).mean(),x.sum(axis=1)/x.sum(axis=1).mean(),c='grey');

# %%
s_bootstrap = bootstrap_s(X,B=10,cores=10)
plt.hist(s_bootstrap,color='lightgray',bins=10,density=True)
plt.axvline(x=s,color='lightsteelblue',linewidth=5)

# %% [markdown]
# # d7

# %%
d7 = pd.read_csv('data/Klein/GSM1599499_ES_d7_LIFminus.csv',)

# %%
data = np.array(d7.to_numpy().T[1:,],dtype=float)
var_names = np.array(d7.to_numpy().T[0,],dtype=str)
data.shape
# Out:
# (798, 24174)

# %%
tc = data.sum(1)
plt.hist(tc);
tc.var()/tc.mean()**2
# Out:
# 0.29992770517895284

# %%
gene_mask = (np.mean(data,axis=0)>0) & (np.var(data,axis=0)>0) 
X = data[:,gene_mask]
cov = np.cov(X,rowvar=False)
X_bar = np.mean(X,axis=0)
X_var = np.diag(cov)

rho = cov/X_bar[:,None]/X_bar[None,:]
s = (np.sum(rho)-np.sum(np.diag(rho)))/(len(rho)-1)/len(rho)
print('s =',s)
# Out:
# s = 0.3220819722911552

# %%
matplotlib.rc('font', size=18)
eta_0 = -1
Ec = 0.04
a = 1 + Ec * (s + 1) * (1 + eta_0)
plt.axhline(y=s, c='b',label='s='+str(np.around(s,3)))
plt.scatter(X_bar, a/X_bar + s,c='r',alpha=1, s=10,label=r'$\frac{1}{\mu}$ + s')
plt.scatter(X_bar, X_var/X_bar**2,c='k',alpha=1, s=0.1)
plt.xlabel(r'$\mu$',fontsize=24)
plt.ylabel(r'$CV^2$',fontsize=24)
plt.title("D7",fontsize=28)
plt.xscale('log')
plt.yscale('log')
plt.legend(loc='upper right')

# %%
Pgene_mask = (X_bar > 0) & (np.abs(X_var/(a*X_bar + s*X_bar**2)-1) < 0.1)
Pgenes = var_names[gene_mask][Pgene_mask]
print(np.sum(Pgene_mask))

plt.scatter(X_bar[Pgene_mask], a/X_bar[Pgene_mask] + s, c='r', s=20)
plt.scatter(X_bar, X_var/X_bar**2,c='lightgray',alpha=1, s=0.1)
plt.scatter(X_bar[Pgene_mask], X_var[Pgene_mask]/X_bar[Pgene_mask]**2,c='k', s=1, label=str(np.around(100*np.sum(Pgene_mask)/len(X_bar),1))+"%")
plt.xlabel(r'$\mu$')
plt.ylabel(r'CV^2')
plt.xscale('log')
plt.yscale('log')
plt.legend()
# Out:
# 14077

# %%
x=X[:,Pgene_mask]
fig,ax = plt.subplots(1,1,figsize=(6,4))
ax.scatter(x.sum(axis=1)/x.sum(axis=1).mean(),data.sum(axis=1)/data.sum(axis=1).mean(),s=10);
ax.plot(x.sum(axis=1)/x.sum(axis=1).mean(),x.sum(axis=1)/x.sum(axis=1).mean(),c='grey');
ax.text(0.9, 0.2, "CCC="+str(np.around(CCC(data.sum(axis=1)/data.sum(axis=1).mean(),x.sum(axis=1)/x.sum(axis=1).mean()))), horizontalalignment='right', 
                 verticalalignment='top', transform=ax.transAxes, color="black",fontsize=20);
ax.set_xlabel("normalized total counts \n (non variable genes)")
ax.set_ylabel("normalized total counts \n (all genes)")
ax.set_title("D7")
# Out:
# Text(0.5, 1.0, 'D7')

# %%
s_bootstrap = bootstrap_s(X,B=100,cores=10)

# %%
matplotlib.rc('font', size=16)
plt.hist(s_bootstrap,color='lightgray',bins=10)
plt.axvline(x=s,color='lightsteelblue',linewidth=5,label="original s")
plt.xlabel("s",fontsize=24)
plt.ylabel("frequency",fontsize=24)
plt.legend(loc=(0.6,0.85))

# %% [markdown]
# # Forebrain

# %%
forebrain = sc.read('data/hgForebrainGlut.loom')

# %%
data = forebrain.X.toarray()

gene_mask = (np.mean(data,axis=0)>0) & (np.var(data,axis=0)>0)
adata = forebrain[:,gene_mask]
X = data[:,gene_mask]

cov = np.cov(X,rowvar=False)
X_bar = np.mean(X,axis=0)
X_var = np.diag(cov)

rho = cov/X_bar[:,None]/X_bar[None,:]
s = (np.sum(rho)-np.sum(np.diag(rho)))/(len(rho)-1)/len(rho)
print('s =',s)
# Out:
# s = 0.20732547085609537

# %%
tc = data.sum(1)
ts = tc.var()/tc.mean()**2
plt.hist(tc)
# Out:
# (array([120., 323., 582., 453., 172.,  38.,  12.,  12.,   6.,   2.]),
#  array([ 1694.,  3188.,  4682.,  6176.,  7670.,  9164., 10658., 12152.,
#         13646., 15140., 16634.], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
a1 = 1
plt.scatter(X_bar, a1/X_bar + s, c='r', s=20)
plt.scatter(X_bar, X_var/X_bar**2, c='k', s=1)
plt.xlabel(r'$\mu$')
plt.ylabel(r'$\sigma^2$')
plt.title("variance-mean relations of forebrain dataset")
plt.xscale('log')
plt.yscale('log')

# %%
a1 = 1
plt.scatter(X_bar, a1/X_bar + ts, c='r', s=20)
plt.scatter(X_bar, X_var/X_bar**2, c='k', s=1)
plt.xlabel(r'$\mu$')
plt.ylabel(r'$\sigma^2$')
plt.title("variance-mean relations of forebrain dataset")
plt.xscale('log')
plt.yscale('log')

# %%
old_Pgenes_s = s
print('old Pgenes_s =', old_Pgenes_s)
Pgene_mask = (X_bar > 0) & (np.abs(X_var/(a*X_bar + old_Pgenes_s*X_bar**2)-1)<0.1)
Pgenes = adata.var_names[Pgene_mask]
print(np.sum(Pgene_mask))

x = X[:,Pgene_mask]
x_cov = np.cov(x,rowvar=False)
x_bar = np.mean(x,axis=0)
x_var = np.diag(x_cov)
x_rho = x_cov/x_bar[:,None]/x_bar[None,:]
new_Pgenes_s = (np.sum(x_rho)-np.sum(np.diag(x_rho)))/(len(x_rho)-1)/len(x_rho)
print('new Pgenes_s =',new_Pgenes_s)
# Out:
# old Pgenes_s = 0.20732547085609537
# 14353
# new Pgenes_s = 0.18047189720980672

# %%
old_Pgenes_s = new_Pgenes_s
print('old Pgenes_s =', old_Pgenes_s)
Pgene_mask = (X_bar > 0) & (np.abs(X_var/(a*X_bar + old_Pgenes_s*X_bar**2)-1)<0.1)
Pgenes = adata.var_names[Pgene_mask]
print(np.sum(Pgene_mask))

x = X[:,Pgene_mask]
x_cov = np.cov(x,rowvar=False)
x_bar = np.mean(x,axis=0)
x_var = np.diag(x_cov)
x_rho = x_cov/x_bar[:,None]/x_bar[None,:]
new_Pgenes_s = (np.sum(x_rho)-np.sum(np.diag(x_rho)))/(len(x_rho)-1)/len(x_rho)
print('new Pgenes_s =',new_Pgenes_s)
# Out:
# old Pgenes_s = 0.18047189720980672
# 14313
# new Pgenes_s = 0.18040952568211152

# %%
Pgene_mask = (X_bar > 0.01) & (np.abs(X_var/(a*X_bar + new_Pgenes_s*X_bar**2)-1) < 0.2)
Pgenes = adata.var_names[Pgene_mask]
print(np.sum(Pgene_mask))

x = X[:,Pgene_mask]
x_cov = np.cov(x,rowvar=False)
x_bar = np.mean(x,axis=0)
x_var = np.diag(x_cov)

x_rho = x_cov/x_bar[:,None]/x_bar[None,:]
Pgenes_s = (np.sum(x_rho)-np.sum(np.diag(x_rho)))/(len(x_rho)-1)/len(x_rho)
print('Pgenes_s =',Pgenes_s)

matplotlib.rc('font', size=18)
a = 1 
plt.axhline(y=Pgenes_s, c='b',label='s='+str(np.around(Pgenes_s,3)))
plt.scatter(X_bar, a/X_bar + Pgenes_s ,c='r',alpha=1, s=10, label=r'$\frac{1}{\mu}$ + s')
plt.scatter(X_bar, X_var/X_bar**2,c='lightgray',alpha=1, s=0.1)
plt.scatter(X_bar[Pgene_mask], X_var[Pgene_mask]/X_bar[Pgene_mask]**2,c='k', s=1, label=str(np.around(100*np.sum(Pgene_mask)/len(X_bar),1))+"%")
plt.xlabel(r'$\mu$')
plt.ylabel(r'$CV^2$',fontsize=24)
plt.xscale('log')
plt.yscale('log')
plt.legend()
# Out:
# 9793
# Pgenes_s = 0.138482015451218

# %%
x=X[:,Pgene_mask]
fig,ax = plt.subplots(1,1,figsize=(6,4))
ax.scatter(x.sum(axis=1)/x.sum(axis=1).mean(),data.sum(axis=1)/data.sum(axis=1).mean(),s=10);
ax.plot(x.sum(axis=1)/x.sum(axis=1).mean(),x.sum(axis=1)/x.sum(axis=1).mean(),c='grey');
ax.text(0.9, 0.2, "CCC="+str(np.around(CCC(data.sum(axis=1)/data.sum(axis=1).mean(),x.sum(axis=1)/x.sum(axis=1).mean()))), horizontalalignment='right', 
                 verticalalignment='top', transform=ax.transAxes, color="black",fontsize=20);
ax.set_xlabel("normalized total counts \n (non variable genes)")
ax.set_ylabel("normalized total counts \n (all genes)")
ax.set_title("Forebrain")
# Out:
# Text(0.5, 1.0, 'Forebrain')

# %%
plt.hist((x_var-x_bar)/x_bar-Pgenes_s*x_bar,bins=1000);
plt.axvline(x=0,c='r')
plt.axvline(x=Ec*(1+s),c='orange')

# %% [markdown]
# ## Clusters

# %%
Clusters = set(adata.obs['Clusters'])
colors20 = np.vstack((plt.cm.tab20b(np.linspace(0., 1, 20))[::2], plt.cm.tab20c(np.linspace(0, 1, 20))[1::2]))

# %%
fig, ax = plt.subplots(1,len(Clusters),figsize=(6*len(Clusters),5),tight_layout=True)
for i,cluster in enumerate(Clusters):
    cell_idx = adata.obs['Clusters'].isin([cluster])
    
    cluster_X = adata.X.toarray()[cell_idx]
    cluster_gene_mask = (np.mean(cluster_X,axis=0)>0) & (np.var(cluster_X,axis=0)>0) 
    cluster_X = cluster_X[:,cluster_gene_mask]
    
    gene_idx = adata.var_names[cluster_gene_mask].isin(Pgenes)
    cluster_X_P = cluster_X[:,gene_idx]
    
    cluster_cov = np.cov(cluster_X_P,rowvar=False)
    cluster_X_bar = np.mean(cluster_X_P,axis=0)
    cluster_rho = cluster_cov/cluster_X_bar[:,None]/cluster_X_bar[None,:]
    cluster_s = (np.sum(cluster_rho)-np.sum(np.diag(cluster_rho)))/(len(cluster_rho)-1)/len(cluster_rho)
    #print(cluster, idx.sum(),'s =',s)
    cluster_X_bar = np.mean(cluster_X,axis=0)
    cluster_X_var = np.var(cluster_X,axis=0)
    idx = adata.var_names[cluster_gene_mask].isin(Pgenes)
    
    ax[i].scatter(cluster_X_bar[idx], a1 / cluster_X_bar[idx] + cluster_s, s=10, color='r')
    ax[i].scatter(cluster_X_bar, cluster_X_var/cluster_X_bar**2, s=0.1, color='gray', alpha=1)
    ax[i].scatter(cluster_X_bar[idx], cluster_X_var[idx]/cluster_X_bar[idx]**2, s=1, color='k', alpha=0.1)
    ax[i].text(0.9, 0.85, str(cell_idx.sum())+' cells \n s='+str(np.round(cluster_s,3)), horizontalalignment='right', 
                 verticalalignment='top', transform=ax[i].transAxes, color="black",fontsize=20);
    ax[i].set_xlabel(r'$\mu$')
    ax[i].set_ylabel(r'CV^2')
    ax[i].set_xscale('log')
    ax[i].set_yscale('log')
    ax[i].set_title("cluster "+str(i),color=colors20[i],fontsize=28)

# %%
fig, ax = plt.subplots(1,33,figsize=(6*33,4))
for i,gene in enumerate(Pgenes):
    gene_idx = forebrain.var_names.isin([gene])
    x = forebrain.X.toarray()[:,gene_idx]
    ax[i].set_title(gene)
    for cluster in range(5,7): #Clusters:
        cell_idx = forebrain.obs['Clusters'].isin([cluster])
        ax[i].hist(x[cell_idx],bins=np.arange(0,2+np.amax(x),2),alpha=0.3,density=True,color=colors20[cluster])
        ax[i].axvline(x[cell_idx].mean(),color=colors20[cluster],label=cluster)
        
plt.legend();

# %%
colors20 = np.vstack((plt.cm.tab20b(np.linspace(0., 1, 20))[::2], plt.cm.tab20c(np.linspace(0, 1, 20))[1::2]))

fig, ax = plt.subplots(1,33,figsize=(6*33,4))
for i,gene in enumerate(Pgenes):
    gene_idx = forebrain.var_names.isin([gene])
    S = forebrain.X.toarray()[:,gene_idx]
    U = forebrain.layers['unspliced'].toarray()[:,gene_idx]
    ax[i].set_title(gene)
    for cluster in range(5,7): #Clusters:
        cell_idx = forebrain.obs['Clusters'].isin([cluster])
        ax[i].plot(U[cell_idx],S[cell_idx],'.',alpha=0.3,color=colors20[cluster])
        
plt.legend();

# %%
from scipy.stats import kruskal

for i,gene in enumerate(Pgenes):
    gene_idx = forebrain.var_names.isin([gene])
    x = forebrain.X.toarray()[:,gene_idx]
    samples =[]
    for cluster in range(5,7):
        cell_idx = forebrain.obs['Clusters'].isin([cluster])
        samples.append(x[cell_idx].reshape((-1)))
    print(kruskal(*samples))
